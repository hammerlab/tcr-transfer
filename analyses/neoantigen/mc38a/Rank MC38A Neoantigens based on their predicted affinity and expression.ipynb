# %% [markdown]
# RNA-seq quantification:
#
# ```
# $ gsutil cp gs://musc-tcr-transfer/output/openvax/201912-mc38a/rna_L001_R1.fastq.gz .
# $ gsutil cp gs://musc-tcr-transfer/output/openvax/201912-mc38a/rna_L001_R2.fastq.gz .
#
# $ wget "http://ftp.ensembl.org/pub/release-103/fasta/mus_musculus/cdna/Mus_musculus.GRCm39.cdna.all.fa.gz"
# $ kallisto index -i Mus_musculus.GRCm39.cdna.all.fa.gz Mus_musculus.GRCm39.cdna.all.fa.gz
#
# $ kallisto quant -o MC38A-kallisto -i Mus_musculus.GRCm39.cdna.all.fa.gz rna_L001_R1.fastq.gz rna_L001_R2.fastq.gz
# ```
#
# Binding prediction:
#
# ```
# $ conda create -n mhc
# $ conda activate mhc
# $ pip install mhcflurry mhctools topiary
# $ pyensembl install --release 102 --species mus_musculus
#
# $ gsutil cp gs://musc-tcr-transfer/output/openvax/201912-mc38a/mutect.vcf .
# $ gsutil cp gs://musc-tcr-transfer/output/openvax/201912-mc38a/strelka.vcf .
#
# $ topiary --mhc-predictor mhcflurry --mhc-alleles "H-2-Kb H-2Db" --vcf mutect.vcf --vcf strelka.vcf --output-csv MC38A-neoepitopes.csv --output-html MC38A-neoepitopes.html
# ```

# %%
library('tidyverse')
# Out:
# ── Attaching packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.4     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
#
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
epitopes <-
    read_csv('MC38A-neoepitopes.csv')

epitopes %>% head
# Out:
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   `#` = col_double(),
#   variant = col_character(),
#   peptide_offset = col_double(),
#   peptide = col_character(),
#   allele = col_character(),
#   score = col_double(),
#   affinity = col_double(),
#   percentile_rank = col_double(),
#   prediction_method_name = col_character(),
#   peptide_length = col_double(),
#   gene = col_character(),
#   gene_id = col_character(),
#   transcript_id = col_character(),
#   transcript_name = col_character(),
#   effect = col_character(),
#   effect_type = col_character(),
#   contains_mutant_residues = col_logical(),
#   mutation_start_in_peptide = col_double(),
#   mutation_end_in_peptide = col_double()
# )
#   # variant             peptide_offset peptide   allele score      affinity
# 1 0 chr8 g.3496674G>C   410            AAAAAAAAP H-2-Db 0.10000466 16945.373
# 2 1 chr5 g.66022672C>T  491            AAAAAAAAT H-2-Db 0.11647544 14179.320
# 3 2 chr8 g.3496674G>C   411            AAAAAAAPA H-2-Db 0.23921349  3757.621
# 4 3 chr5 g.66022672C>T  492            AAAAAAATA H-2-Db 0.22478828  4392.347
# 5 4 chr6 g.125101598G>T 219            AAAAAAAVS H-2-Db 0.08228799 20525.853
# 6 5 chr8 g.3496674G>C   412            AAAAAAPAA H-2-Db 0.20740198  5301.446
#   percentile_rank prediction_method_name peptide_length gene
# 1  7.455250       mhcflurry              9              Zfp358
# 2  5.814500       mhcflurry              9              Rbm47
# 3  1.894250       mhcflurry              9              Zfp358
# 4  2.102125       mhcflurry              9              Rbm47
# 5 10.252875       mhcflurry              9              Chd4
# 6  2.403125       mhcflurry              9              Zfp358
#   gene_id            transcript_id      transcript_name effect  effect_type
# 1 ENSMUSG00000047264 ENSMUST00000208423 Zfp358-203      p.A419P Substitution
# 2 ENSMUSG00000070780 ENSMUST00000201544 Rbm47-209       p.A500T Substitution
# 3 ENSMUSG00000047264 ENSMUST00000208423 Zfp358-203      p.A419P Substitution
# 4 ENSMUSG00000070780 ENSMUST00000201544 Rbm47-209       p.A500T Substitution
# 5 ENSMUSG00000063870 ENSMUST00000056889 Chd4-201        p.A228S Substitution
# 6 ENSMUSG00000047264 ENSMUST00000208423 Zfp358-203      p.A419P Substitution
#   contains_mutant_residues mutation_start_in_peptide mutation_end_in_peptide
# 1 TRUE                     8                         9
# 2 TRUE                     8                         9
# 3 TRUE                     7                         8
# 4 TRUE                     7                         8
# 5 TRUE                     8                         9
# 6 TRUE                     6                         7

# %%
exp_tbl <-
    read_tsv('./MC38A-kallisto/abundance.tsv') %>%
    separate(`target_id`, c('transcript_id', 't_version'), sep='\\.')

exp_tbl %>% head
# Out:
# ── Column specification ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# cols(
#   target_id = col_character(),
#   length = col_double(),
#   eff_length = col_double(),
#   est_counts = col_double(),
#   tpm = col_double()
# )
#   transcript_id      t_version length eff_length est_counts tpm
# 1 ENSMUST00000178537 2         12      3.0       0          0
# 2 ENSMUST00000178862 2         14      3.5       0          0
# 3 ENSMUST00000196221 2          9     10.0       0          0
# 4 ENSMUST00000179664 2         11      2.0       0          0
# 5 ENSMUST00000177564 2         16      5.5       0          0
# 6 ENSMUST00000179520 2         11      2.0       0          0

# %%
neoantigens_tbl <-
    epitopes %>%
    left_join(
        exp_tbl %>% select(`transcript_id`, `est_counts`, `TPM`=`tpm`), 
        by='transcript_id'
    ) %>%
    arrange(`affinity`) %>%
    select(-`#`) %>%
    relocate(`gene`, `peptide`, `allele`, `affinity`, `TPM`)
    

neoantigens_tbl
# Out:
#       gene          peptide   allele affinity TPM
# 1     Slit1         SSFKHMPKL H-2-Kb 16.88022  0.02979910
# 2     Aldh1l1       SSYPWRSSM H-2-Kb 19.93408  0.00000000
# 3     Adpgk         ASMTNMELM H-2-Db 20.89715 24.29980000
# 4     Olfr781       MSYDRYVAM H-2-Kb 20.96976  0.04039030
# 5     Olfr1442      ISFIYFNNV H-2-Kb 21.28552  0.00000000
# 6     Hdgfl2        KGYPHWPAL H-2-Kb 21.38661 10.06590000
# 7     Zfc3h1        SNYEFPNRV H-2-Kb 22.12009  8.23265000
# 8     Zbtb40        KSFHFYCPL H-2-Kb 22.34975 15.95300000
# 9     Irgq          AALLNSAVL H-2-Db 23.12299 13.02770000
# 10    1700013G24Rik SSYTKALSL H-2-Kb 23.25887  0.03840650
# 11    Olfr1109      TMYFFLSNL H-2-Kb 23.58325  0.00000000
# 12    Olfr516       MSYDRFAAI H-2-Kb 23.60839  0.00000000
# 13    Olfr354       VVILFYGSL H-2-Kb 24.28891  0.00000000
# 14    Kmt2b         SNFHFMCAL H-2-Kb 24.55186 14.44430000
# 15    Klf17         KSYTKSSHL H-2-Kb 24.82213  0.04194300
# 16    Nfasc         TALSNRILL H-2-Db 24.84879  0.05274320
# 17    Olfr1356      YSLRNKDML H-2-Db 25.16359  0.00000000
# 18    Olfr430       SVLSFLELL H-2-Kb 25.89459  0.00000000
# 19    Klrb1a        FTFLKFPTL H-2-Kb 25.94536  0.00000000
# 20    Gsdma         FSLHFFAPL H-2-Kb 26.31281  0.05454940
# 21    Flrt2         CTFSHLTKL H-2-Kb 26.42823  2.23977000
# 22    Herc6         CVYEHTAVL H-2-Kb 26.88844  8.19646000
# 23    Spata5        VSYDMIGGL H-2-Kb 26.91850 16.88990000
# 24    Cpne9         TVYEVLNPL H-2-Kb 27.19301  0.21764500
# 25    Gm5142        YVFPNSVHL H-2-Kb 27.22275  0.06176120
# 26    Gm5142        YVFPNSVHL H-2-Db 27.40028  0.06176120
# 27    Hunk          VTYHNRISL H-2-Kb 27.55858  0.49216800
# 28    Kcnk18        RAYSRFQSL H-2-Kb 28.35680  0.00930006
# 29    Olfr484       MAYDRFVEI H-2-Kb 28.51522  0.02079710
# 30    Abhd12b       ASLSNGNPI H-2-Db 28.59937  0.00000000
# ⋮     ⋮             ⋮         ⋮      ⋮        ⋮
# 60895 Olfr1189      PLTVKTRIN H-2-Db 32038.09  0.02799360
# 60896 Ripk2         QKSSASVKH H-2-Db 32058.13 13.93900000
# 60897 Tmem178       RKCYFLAID H-2-Db 32074.88  0.05225810
# 60898 Rhox2a        LKRRDKYRS H-2-Db 32080.57  0.35030800
# 60899 Gm3594        LKEKCWRSS H-2-Db 32086.14  0.00000000
# 60900 Col11a1       KKTVAMIVD H-2-Db 32087.64  0.12294800
# 60901 Dlc1          NKRVCMYLE H-2-Db 32090.60  0.00000000
# 60902 Lrfn3         NCELVWLRH H-2-Db 32095.59 35.93080000
# 60903 Hacd2         PHLYFHMIH H-2-Db 32118.33 18.19720000
# 60904 Tctn3         PFKAALRRG H-2-Db 32122.01  3.71794000
# 60905 Ankk1         PLLIATLDQ H-2-Db 32126.98  0.04378950
# 60906 Olfr1537      LKKYLKEKN H-2-Db 32130.72  0.08137870
# 60907 Vmn2r76       FKEFILTAH H-2-Db 32175.45  0.00000000
# 60908 Dock4         WKQLFVRNE H-2-Db 32183.87  1.29142000
# 60909 Cep152        RKTTSDRCS H-2-Db 32246.24  6.92479000
# 60910 Vmn2r4        LKEFLYEVH H-2-Db 32249.43  0.06741950
# 60911 Dnajc28       IKRMYAGQD H-2-Db 32285.25  0.48388900
# 60912 Nsd1          PLKILSKWE H-2-Db 32289.52 19.73670000
# 60913 Apob          SKRVAWRYD H-2-Db 32309.60  0.03911960
# 60914 Gm3149        IKEKCWRRS H-2-Db 32309.75  0.00000000
# 60915 Sema5a        PVEVPFYYN H-2-Db 32328.98  4.20460000
# 60916 Cobl          IKELYVWDN H-2-Db 32337.93  0.00000000
# 60917 Cd22          QKTWKQNRS H-2-Db 32339.53  0.02807480
# 60918 Grm5          RKCWAVREQ H-2-Db 32456.06  0.16803500
# 60919 Med12         YKTSVYRHQ H-2-Db 32481.03  4.40603000
# 60920 Hnf4a         CFRAAMKKE H-2-Db 32485.76  0.00672147
# 60921 Ppp4r4        PVTKALRRN H-2-Db 32497.81  3.55091000
# 60922 Dock4         WKQLYLRNE H-2-Db 32519.15  1.29142000
# 60923 Pcsk9         LKTRAARRG H-2-Db 32574.98  0.06407790
# 60924 Slu7          PNSHMEKDH H-2-Db 32576.28 37.51370000
#       variant                                  peptide_offset score
# 1     chr19 g.41651178G>T                       198           0.7387985
# 2     chr6 g.90557285_90557285delA               87           0.7234296
# 3     chr9 g.59313823G>T                        298           0.7190688
# 4     chr10 g.129333251C>G                      114           0.7187483
# 5     chr19 g.12674310C>A                        28           0.7173669
# 6     chr17 g.56079825G>T                        15           0.7169290
# 7     chr10 g.115427783A>C                     1837           0.7138124
# 8     chr4 g.136995463C>G                       760           0.7128578
# 9     chr7 g.24531801G>T                        131           0.7097143
# 10    chr4 g.137454992C>A                       149           0.7091727
# 11    chr2 g.87093224G>T                         57           0.7078927
# 12    chr7 g.108845654C>A                       117           0.7077942
# 13    chr2 g.36907701C>A                        249           0.7051677
# 14    chr7 g.30577370C>A                       1665           0.7041725
# 15    chr4 g.117760351G>T                       264           0.7031607
# 16    chr1 g.132634638C>A                       125           0.7030615
# 17    chr10 g.78847021T>A                       289           0.7018980
# 18    chr1 g.174069514G>T                        63           0.6992513
# 19    chr6 g.128618586_128618586delT            111           0.6990703
# 20    chr11 g.98669759C>A                       175           0.6977705
# 21    chr12 g.95779559G>T                       223           0.6973660
# 22    chr6 g.57600031G>T                        241           0.6957704
# 23    chr3 g.37432182C>G                        349           0.6956672
# 24    chr6 g.113292535G>T                       252           0.6947294
# 25    chr14 g.59178625G>T                        23           0.6946284
# 26    chr14 g.59178625G>T                        23           0.6940276
# 27    chr16 g.90472573C>A                       331           0.6934952
# 28    chr19 g.59234959G>T                       171           0.6908562
# 29    chr7 g.108124879G>T                       120           0.6903413
# 30    chr12 g.70163451G>A                       129           0.6900690
# ⋮     ⋮                                        ⋮              ⋮
# 60895 chr2 g.88592635_88592636insTCATACGGCAAAC  309           0.04113740
# 60896 chr4 g.16151943C>A                        201           0.04107960
# 60897 chr17 g.80945053G>C                       115           0.04103132
# 60898 chrX g.37249484G>T                        178           0.04101493
# 60899 chr14 g.6436863C>A                        221           0.04099890
# 60900 chr3 g.114066452A>G                       171           0.04099457
# 60901 chr8 g.36584211C>A                        784           0.04098603
# 60902 chr7 g.30360014C>T                        253           0.04097166
# 60903 chr16 g.35106325G>T                       229           0.04090620
# 60904 chr19 g.40597396G>T                       561           0.04089562
# 60905 chr9 g.49416643T>A                        405           0.04088132
# 60906 chr9 g.39237513_39237513delT              300           0.04087057
# 60907 chr7 g.86230081T>A                        331           0.04074200
# 60908 chr12 g.40631614A>T                        99           0.04071781
# 60909 chr2 g.125583971C>A                       817           0.04053887
# 60910 chr3 g.64406509A>T                        343           0.04052972
# 60911 chr16 g.91617033G>A                       127           0.04042713
# 60912 chr13 g.55245525A>T                       414           0.04041491
# 60913 chr12 g.8001932A>G                       1161           0.04035745
# 60914 chr14 g.4324631C>A                        221           0.04035702
# 60915 chr15 g.32562689G>T                       280           0.04030202
# 60916 chr11 g.12375827G>A                       217           0.04027643
# 60917 chr7 g.30867963T>G                        729           0.04027187
# 60918 chr7 g.87602715G>T                         54           0.03993943
# 60919 chrX g.101293573G>T                      1894           0.03986835
# 60920 chr2 g.163552640G>C                       119           0.03985489
# 60921 chr12 g.103601494_103601494delA           725           0.03982063
# 60922 chr12 g.40631616G>C                        99           0.03975995
# 60923 chr4 g.106458941G>T                       100           0.03960142
# 60924 chr11 g.43441265G>C                       224           0.03959772
#       percentile_rank prediction_method_name peptide_length gene_id
# 1     0.003500        mhcflurry              9              ENSMUSG00000025020
# 2     0.011250        mhcflurry              9              ENSMUSG00000030088
# 3     0.000500        mhcflurry              9              ENSMUSG00000025236
# 4     0.013375        mhcflurry              9              ENSMUSG00000095138
# 5     0.014625        mhcflurry              9              ENSMUSG00000044441
# 6     0.014625        mhcflurry              9              ENSMUSG00000002833
# 7     0.016875        mhcflurry              9              ENSMUSG00000034163
# 8     0.017375        mhcflurry              9              ENSMUSG00000060862
# 9     0.001000        mhcflurry              9              ENSMUSG00000041037
# 10    0.020000        mhcflurry              9              ENSMUSG00000041399
# 11    0.020625        mhcflurry              9              ENSMUSG00000075161
# 12    0.020625        mhcflurry              9              ENSMUSG00000062434
# 13    0.022875        mhcflurry              9              ENSMUSG00000055088
# 14    0.023875        mhcflurry              9              ENSMUSG00000006307
# 15    0.025250        mhcflurry              9              ENSMUSG00000048626
# 16    0.001875        mhcflurry              9              ENSMUSG00000026442
# 17    0.001875        mhcflurry              9              ENSMUSG00000051190
# 18    0.029625        mhcflurry              9              ENSMUSG00000050134
# 19    0.029625        mhcflurry              9              ENSMUSG00000030361
# 20    0.030250        mhcflurry              9              ENSMUSG00000017204
# 21    0.031375        mhcflurry              9              ENSMUSG00000047414
# 22    0.032000        mhcflurry              9              ENSMUSG00000029798
# 23    0.033000        mhcflurry              9              ENSMUSG00000027722
# 24    0.033000        mhcflurry              9              ENSMUSG00000030270
# 25    0.034125        mhcflurry              9              ENSMUSG00000053868
# 26    0.002500        mhcflurry              9              ENSMUSG00000053868
# 27    0.035750        mhcflurry              9              ENSMUSG00000053414
# 28    0.038250        mhcflurry              9              ENSMUSG00000040901
# 29    0.039500        mhcflurry              9              ENSMUSG00000110171
# 30    0.003750        mhcflurry              9              ENSMUSG00000090121
# ⋮     ⋮               ⋮                      ⋮              ⋮
# 60895 63.59413        mhcflurry              9              ENSMUSG00000068808
# 60896 63.59413        mhcflurry              9              ENSMUSG00000041135
# 60897 68.60925        mhcflurry              9              ENSMUSG00000024245
# 60898 68.60925        mhcflurry              9              ENSMUSG00000051827
# 60899 68.60925        mhcflurry              9              ENSMUSG00000095360
# 60900 68.60925        mhcflurry              9              ENSMUSG00000027966
# 60901 68.60925        mhcflurry              9              ENSMUSG00000031523
# 60902 68.60925        mhcflurry              9              ENSMUSG00000036957
# 60903 68.60925        mhcflurry              9              ENSMUSG00000035376
# 60904 68.60925        mhcflurry              9              ENSMUSG00000025008
# 60905 68.60925        mhcflurry              9              ENSMUSG00000032257
# 60906 68.60925        mhcflurry              9              ENSMUSG00000096109
# 60907 68.60925        mhcflurry              9              ENSMUSG00000091239
# 60908 68.60925        mhcflurry              9              ENSMUSG00000035954
# 60909 68.60925        mhcflurry              9              ENSMUSG00000068394
# 60910 68.60925        mhcflurry              9              ENSMUSG00000092049
# 60911 68.60925        mhcflurry              9              ENSMUSG00000039763
# 60912 68.60925        mhcflurry              9              ENSMUSG00000021488
# 60913 68.60925        mhcflurry              9              ENSMUSG00000020609
# 60914 68.60925        mhcflurry              9              ENSMUSG00000079389
# 60915 68.60925        mhcflurry              9              ENSMUSG00000022231
# 60916 68.60925        mhcflurry              9              ENSMUSG00000020173
# 60917 68.60925        mhcflurry              9              ENSMUSG00000030577
# 60918 73.79475        mhcflurry              9              ENSMUSG00000049583
# 60919 73.79475        mhcflurry              9              ENSMUSG00000079487
# 60920 73.79475        mhcflurry              9              ENSMUSG00000017950
# 60921 73.79475        mhcflurry              9              ENSMUSG00000021209
# 60922 73.79475        mhcflurry              9              ENSMUSG00000035954
# 60923 73.79475        mhcflurry              9              ENSMUSG00000044254
# 60924 73.79475        mhcflurry              9              ENSMUSG00000020409
#       transcript_id      transcript_name   effect   effect_type
# 1     ENSMUST00000025993 Slit1-201         p.N202K  Substitution
# 2     ENSMUST00000130418 Aldh1l1-203       p.K21fs  FrameShift
# 3     ENSMUST00000217570 Adpgk-205         p.R304M  Substitution
# 4     ENSMUST00000204108 Olfr781-202       p.I123M  Substitution
# 5     ENSMUST00000208494 Olfr1442-203      p.T35N   Substitution
# 6     ENSMUST00000225843 Hdgfl2-210        p.R24L   Substitution
# 7     ENSMUST00000036044 Zfc3h1-201        p.H1843P Substitution
# 8     ENSMUST00000049583 Zbtb40-201        p.R768P  Substitution
# 9     ENSMUST00000049020 Irgq-201          p.G139V  Substitution
# 10    ENSMUST00000048893 1700013G24Rik-201 p.P153T  Substitution
# 11    ENSMUST00000214636 Olfr1109-202      p.P58T   Substitution
# 12    ENSMUST00000216092 Olfr516-202       p.A119S  Substitution
# 13    ENSMUST00000217479 Olfr354-202       p.L252I  Substitution
# 14    ENSMUST00000006470 Kmt2b-201         p.R1674L Substitution
# 15    ENSMUST00000062747 Klf17-201         p.R270S  Substitution
# 16    ENSMUST00000187861 Nfasc-207         p.R133L  Substitution
# 17    ENSMUST00000205100 Olfr1356-202      p.Q298L  Substitution
# 18    ENSMUST00000213425 Olfr430-202       p.W72L   Substitution
# 19    ENSMUST00000032512 Klrb1a-201        p.Q102fs FrameShift
# 20    ENSMUST00000017348 Gsdma-201         p.P179H  Substitution
# 21    ENSMUST00000057324 Flrt2-201         p.G224C  Substitution
# 22    ENSMUST00000031817 Herc6-201         p.G243V  Substitution
# 23    ENSMUST00000108112 Spata5-202        p.T351S  Substitution
# 24    ENSMUST00000041203 Cpne9-201         p.R261L  Substitution
# 25    ENSMUST00000066558 Gm5142-201        p.T28N   Substitution
# 26    ENSMUST00000066558 Gm5142-201        p.T28N   Substitution
# 27    ENSMUST00000065856 Hunk-201          p.P335H  Substitution
# 28    ENSMUST00000065204 Kcnk18-201        p.A179S  Substitution
# 29    ENSMUST00000214722 Olfr484-202       p.A128E  Substitution
# 30    ENSMUST00000169156 Abhd12b-203       p.D134N  Substitution
# ⋮     ⋮                  ⋮                 ⋮        ⋮
# 60895 ENSMUST00000213679 Olfr1189-202      p.E277fs FrameShift
# 60896 ENSMUST00000037035 Ripk2-201         p.R205S  Substitution
# 60897 ENSMUST00000025092 Tmem178-201       p.G122A  Substitution
# 60898 ENSMUST00000063340 Rhox2a-201        p.E183D  Substitution
# 60899 ENSMUST00000171784 Gm3594-202        p.R229S  Substitution
# 60900 ENSMUST00000092155 Col11a1-201       p.T176A  Substitution
# 60901 ENSMUST00000163663 Dlc1-206          p.G789C  Substitution
# 60902 ENSMUST00000046351 Lrfn3-201         p.R262H  Substitution
# 60903 ENSMUST00000061156 Hacd2-201         p.Q231H  Substitution
# 60904 ENSMUST00000025981 Tctn3-201         p.S568R  Substitution
# 60905 ENSMUST00000034792 Ankk1-201         p.Q412L  Substitution
# 60906 ENSMUST00000213472 Olfr1537-202      p.I304fs FrameShift
# 60907 ENSMUST00000165771 Vmn2r76-201       p.Q337L  Substitution
# 60908 ENSMUST00000037488 Dock4-201         p.Y104F  Substitution
# 60909 ENSMUST00000089776 Cep152-201        p.G825C  Substitution
# 60910 ENSMUST00000175724 Vmn2r4-202        p.D350E  Substitution
# 60911 ENSMUST00000169982 Dnajc28-204       p.H132Y  Substitution
# 60912 ENSMUST00000099490 Nsd1-201          p.Q416L  Substitution
# 60913 ENSMUST00000037811 Apob-202          p.T1166A Substitution
# 60914 ENSMUST00000171810 Gm3149-202        p.L222I  Substitution
# 60915 ENSMUST00000067458 Sema5a-201        p.G282V  Substitution
# 60916 ENSMUST00000046755 Cobl-201          p.A223V  Substitution
# 60917 ENSMUST00000019248 Cd22-201          p.K732T  Substitution
# 60918 ENSMUST00000125009 Grm5-202          p.G58W   Substitution
# 60919 ENSMUST00000117706 Med12-204         p.Q1902H Substitution
# 60920 ENSMUST00000018094 Hnf4a-201         p.G124A  Substitution
# 60921 ENSMUST00000021631 Ppp4r4-201        p.N691fs FrameShift
# 60922 ENSMUST00000037488 Dock4-201         p.V105L  Substitution
# 60923 ENSMUST00000049507 Pcsk9-201         p.Q102K  Substitution
# 60924 ENSMUST00000020681 Slu7-201          p.Q228H  Substitution
#       contains_mutant_residues mutation_start_in_peptide
# 1     TRUE                     3
# 2     TRUE                     0
# 3     TRUE                     5
# 4     TRUE                     8
# 5     TRUE                     6
# 6     TRUE                     8
# 7     TRUE                     5
# 8     TRUE                     7
# 9     TRUE                     7
# 10    TRUE                     3
# 11    TRUE                     0
# 12    TRUE                     1
# 13    TRUE                     2
# 14    TRUE                     8
# 15    TRUE                     5
# 16    TRUE                     7
# 17    TRUE                     8
# 18    TRUE                     8
# 19    TRUE                     0
# 20    TRUE                     3
# 21    TRUE                     0
# 22    TRUE                     1
# 23    TRUE                     1
# 24    TRUE                     8
# 25    TRUE                     4
# 26    TRUE                     4
# 27    TRUE                     3
# 28    TRUE                     7
# 29    TRUE                     7
# 30    TRUE                     4
# ⋮     ⋮                        ⋮
# 60895 TRUE                     0
# 60896 TRUE                     3
# 60897 TRUE                     6
# 60898 TRUE                     4
# 60899 TRUE                     7
# 60900 TRUE                     4
# 60901 TRUE                     4
# 60902 TRUE                     8
# 60903 TRUE                     1
# 60904 TRUE                     6
# 60905 TRUE                     6
# 60906 TRUE                     3
# 60907 TRUE                     5
# 60908 TRUE                     4
# 60909 TRUE                     7
# 60910 TRUE                     6
# 60911 TRUE                     4
# 60912 TRUE                     1
# 60913 TRUE                     4
# 60914 TRUE                     0
# 60915 TRUE                     1
# 60916 TRUE                     5
# 60917 TRUE                     2
# 60918 TRUE                     3
# 60919 TRUE                     7
# 60920 TRUE                     4
# 60921 TRUE                     0
# 60922 TRUE                     5
# 60923 TRUE                     1
# 60924 TRUE                     3
#       mutation_end_in_peptide est_counts
# 1     4                          9.56654
# 2     9                          0.00000
# 3     6                       3613.47000
# 4     9                          2.79909
# 5     7                          0.00000
# 6     9                       1330.21000
# 7     6                       3702.18000
# 8     8                       7426.24000
# 9     8                       5092.30000
# 10    4                          2.00000
# 11    1                          0.00000
# 12    2                          0.00000
# 13    3                          0.00000
# 14    9                       7965.13000
# 15    6                          6.00000
# 16    8                         16.51360
# 17    9                          0.00000
# 18    9                          0.00000
# 19    9                          0.00000
# 20    4                          9.00000
# 21    1                       1028.62000
# 22    2                       2478.02000
# 23    2                       3433.32000
# 24    9                         36.65580
# 25    5                          1.50000
# 26    5                          1.50000
# 27    4                        169.52800
# 28    8                          2.00000
# 29    8                          6.16021
# 30    5                          0.00000
# ⋮     ⋮                       ⋮
# 60895 9                           3.21902
# 60896 4                        2267.88000
# 60897 7                           5.00000
# 60898 5                          12.30810
# 60899 8                           0.00000
# 60900 5                          61.16330
# 60901 5                           0.00000
# 60902 9                        6315.00000
# 60903 2                        4070.09000
# 60904 7                         617.66800
# 60905 7                           7.18938
# 60906 9                          21.02720
# 60907 6                           0.00000
# 60908 5                         719.35100
# 60909 8                        2560.00000
# 60910 7                          36.81930
# 60911 5                         106.17800
# 60912 2                       16614.30000
# 60913 5                          35.95800
# 60914 1                           0.00000
# 60915 2                        2980.63000
# 60916 6                           0.00000
# 60917 3                           6.98969
# 60918 4                          87.88910
# 60919 8                        1976.33000
# 60920 5                           1.84620
# 60921 9                         881.66800
# 60922 6                         719.35100
# 60923 2                          14.00000
# 60924 4                        8458.69000

# %%
neoantigens_tbl %>%
    write_csv('MC38A-neoantigens_with_expression.csv')
